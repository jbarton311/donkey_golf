# %%
import sqlite3
import pandas as pd

# %%
cd ..
# Out:
# /home/greenman225/Code/github/donkey_golf

# %%
from donkey_golf import data_utils as du
# Out:
# /home/greenman225/Code/virtual_envs/donkey_env/lib/python3.6/site-packages/flask_sqlalchemy/__init__.py:794: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '

# %%
du.pull_available_players()
# Out:
#                   player  tee_time  current_rank  events_played  rank    tier
# 0    Kevin O'Connell (a)   8:52 AM           NaN            NaN   NaN  Tier 2
# 1      Takumi Kanaya (a)   9:14 AM           NaN            NaN   NaN  Tier 2
# 2             Si Woo Kim   9:25 AM           NaN            NaN   NaN  Tier 2
# 3     Viktor Hovland (a)  10:31 AM           NaN            NaN   NaN  Tier 2
# 4             Li Haotong  11:04 AM           NaN            NaN   NaN  Tier 2
# 5        Devon Bling (a)  11:37 AM           NaN            NaN   NaN  Tier 2
# 6    Jose Maria Olazabal  11:59 AM           NaN            NaN   NaN  Tier 2
# 7       Alvaro Ortiz (a)  12:10 PM           NaN            NaN   NaN  Tier 2
# 8        Alexander Noren  12:32 PM           NaN            NaN   NaN  Tier 2
# 9       Jovan Rebula (a)  12:43 PM           NaN            NaN   NaN  Tier 2
# 10  Rafael Cabrera Bello   1:16 PM           NaN            NaN   NaN  Tier 2
# 11           Justin Rose   1:49 PM           1.0           46.0   1.0  Tier 1
# 12        Dustin Johnson   1:38 PM           2.0           46.0   2.0  Tier 1
# 13          Rory McIlroy  11:15 AM           3.0           45.0   3.0  Tier 1
# 14         Brooks Koepka   2:00 PM           4.0           43.0   4.0  Tier 1
# 15         Justin Thomas   1:49 PM           5.0           47.0   5.0  Tier 1
# 16     Bryson DeChambeau   1:38 PM           6.0           56.0   6.0  Tier 1
# 17    Francesco Molinari   1:16 PM           7.0           47.0   7.0  Tier 1
# 18              Jon Rahm  11:04 AM           8.0           51.0   8.0  Tier 1
# 19         Rickie Fowler  11:15 AM           9.0           45.0   9.0  Tier 1
# 20     Xander Schauffele  10:53 AM          10.0           56.0  10.0  Tier 1
# 21            Paul Casey   2:00 PM          11.0           47.0  11.0  Tier 1
# 22           Tiger Woods  11:04 AM          12.0           25.0  12.0  Tier 1
# 23       Tommy Fleetwood  10:53 AM          13.0           57.0  13.0  Tier 2
# 24             Jason Day   1:38 PM          14.0           42.0  14.0  Tier 2
# 25            Tony Finau   9:58 AM          15.0           55.0  15.0  Tier 2
# 26           Matt Kuchar   1:05 PM          16.0           56.0  16.0  Tier 2
# 27          Bubba Watson   1:27 PM          17.0           46.0  17.0  Tier 2
# 28          Patrick Reed  10:31 AM          18.0           61.0  18.0  Tier 2
# 29      Louis Oosthuizen  10:42 AM          19.0           42.0  19.0  Tier 2
# ..                   ...       ...           ...            ...   ...     ...
# 57           Shane Lowry   8:52 AM          50.0           55.0  47.0  Tier 2
# 58      Thorbjorn Olesen  11:59 AM          53.0           50.0  48.0  Tier 2
# 59              Kevin Na  11:59 AM          54.0           50.0  49.0  Tier 2
# 60       Emiliano Grillo   9:36 AM          59.0           52.0  50.0  Tier 2
# 61        Keith Mitchell   8:41 AM          60.0           59.0  51.0  Tier 2
# 62       Charley Hoffman  10:42 AM          66.0           55.0  52.0  Tier 2
# 63            Aaron Wise   9:03 AM          67.0           51.0  53.0  Tier 2
# 64       Satoshi Kodaira   1:27 PM          68.0           63.0  54.0  Tier 2
# 65         Shugo Imahira  12:54 PM          77.0           55.0  55.0  Tier 2
# 66         Danny Willett   9:14 AM          78.0           47.0  56.0  Tier 2
# 67         Corey Conners   8:30 AM          84.0           63.0  57.0  Tier 2
# 68          Zach Johnson   1:05 PM          87.0           47.0  58.0  Tier 2
# 69          Stewart Cink  11:48 AM          96.0           49.0  59.0  Tier 2
# 70        Patton Kizzire  11:26 AM          97.0           56.0  60.0  Tier 2
# 71            Kevin Tway   8:41 AM          98.0           58.0  61.0  Tier 2
# 72          Jimmy Walker  11:48 AM         102.0           43.0  62.0  Tier 2
# 73      Charl Schwartzel   9:47 AM         104.0           51.0  63.0  Tier 2
# 74             Adam Long   8:30 AM         108.0           59.0  64.0  Tier 2
# 75         Andrew Landry   8:30 AM         128.0           56.0  65.0  Tier 2
# 76         Martin Kaymer  11:37 AM         190.0           52.0  66.0  Tier 2
# 77           Michael Kim  11:26 AM         330.0           54.0  67.0  Tier 2
# 78       Trevor Immelman  11:37 AM         461.0           27.0  68.0  Tier 2
# 79           Vijay Singh  12:43 PM         480.0           26.0  69.0  Tier 2
# 80       Bernhard Langer  12:10 PM         835.0            3.0  70.0  Tier 2
# 81          Fred Couples   9:25 AM        1330.0            3.0  71.0  Tier 2
# 82         Angel Cabrera   9:03 AM        1575.0           29.0  72.0  Tier 2
# 83             Mike Weir   8:52 AM        1765.0           27.0  73.0  Tier 2
# 84           Ian Woosnam   8:41 AM        2035.0            1.0  74.0  Tier 2
# 85            Sandy Lyle  11:26 AM        2035.0            3.0  74.0  Tier 2
# 86            Larry Mize  11:48 AM        2035.0            1.0  74.0  Tier 2
#
# [87 rows x 6 columns]

# %%
	name
0	user
1	pre_tourney
2	rankings

# %%
du.run_sql("SELECT * FROM rankings WHERE player LIKE ('%Kim%')")

# %%
du.run_sql('SELECT * FROM pre_tourney LIMIT 5')

# %%
def pull_
sql = '''SELECT a.*, b.current_rank, b.events_played FROM pre_tourney a
LEFT JOIN rankings b ON a.player=b.player
ORDER BY current_rank
'''
du.run_sql(sql)

# %%
du.run_sql('SELECT * ')

# %%
du.data_load_rankings()

# %%
import data_utils as du

# %%
du.pull_available_players()

# %%
du.data_load_leaderboard()

# %%
du.data_load_rankings()

# %%
du.run_sql('SELECT * FROM pre_tourney')

# %%
result = du.scrape_espn_leaderboard()

# %%
du.load_table_to_db(result.get('pre_tourney'), 'pre_tourney')

# %%
result.get('pre_tourney')

# %%
# Creating leaderboard & rankings dataframes
leaderboard = pd.read_html('http://www.espn.com/golf/leaderboard',header=3)[0]

leaderboard.columns = leaderboard.columns.str.lower().str.replace(' ','_')

if leaderboard.columns.tolist() == ['player', 'tee_time']:
    print("pre_tourney")

# %%
if leaderboard.columns.tolist() == ['player', 'tee_time']:
    print("pre_tourney")

# %%
conn = sqlite3.connect('/home/greenman225/Code/github/donkey_golf/donkey_golf/site.db')

# %%
pwd

# %%
du.scrape_espn_leaderboard()

# %%
du.data_load_leaderboard()

# %% [markdown]
# # Show all tables in our database

# %%
pd.read_sql('SELECT name FROM sqlite_master WHERE type = "table"', conn)

# %%
pd.read_sql('SELECT * from user', conn)
