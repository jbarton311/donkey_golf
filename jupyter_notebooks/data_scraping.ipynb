# %%
import sqlite3
import pandas as pd

# %%
cd ..
# Out:
# /home/greenman225/Code/github/donkey_golf

# %%
from donkey_golf import data_utils as du
# Out:
# /home/greenman225/Code/virtual_envs/donkey_env/lib/python3.6/site-packages/flask_sqlalchemy/__init__.py:794: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '
# /home/greenman225/Code/github/donkey_golf/donkey_golf/data_utils.py:27: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_sql_dict = oyaml.load(open(conf.yaml_sql_loc))

# %%
df = du.pull_tourney_leaderboard(6)

# %%
for i, row in df.iterrows():
    if row['pos'].lower().startswith('projected'):
        print(row['pos'])
# Out:
# Projected Cut +4

# %%
def calculate_cut_line():
    df = du.run_sql("SELECT pos FROM leaderboard WHERE pos LIKE ('%projected%') LIMIT 1")

    # Grab the cut_str
    cut_str = df['pos'][0].lower()

    # Get rid of unneeded string
    cut_str = cut_str.replace('projected cut ','')

    # Put both string and int representations into a dict
    cut_dict = {}
    cut_dict['cut_str'] = cut_str
    cut_dict['cut_int'] = int(cut_str.replace('+', '').replace('E', '0'))
    
    return cut_dict

# %%
calculate_cut_line()
# Out:
# {'cut_str': '+4', 'cut_int': 4}

# %%
cut_dict
# Out:
# {'cut_str': '+4', 'cut_int': 4}

# %%
du.aggregate_team_score()
# Out:
#    id username  user_score  rank
# 3   7    tiger         -28     1
# 4   9     donk         -28     1
# 2   6     jeff          -3     3
# 0   4      poo           7     4
# 1   5     mike           9     5

# %%
du.users_team(6)
# Out:
#    id tourney_id           golfer  pos           player to_par thru  r1  r2  \
# 0   6  401056527   Dustin Johnson   T4   Dustin Johnson     -4    F  68  --
# 1   6  401056527        Jason Day  T11        Jason Day     -2    F  70  --
# 2   6  401056527      Justin Rose  T63      Justin Rose     +3    F  75  --
# 3   6  401056527     Rory McIlroy  T44     Rory McIlroy     +1    F  73  --
# 4   6  401056527       Si Woo Kim  T29       Si Woo Kim      E    F  72  --
# 5   6  401056527  Tommy Fleetwood  T21  Tommy Fleetwood     -1    F  71  --
#
#    r3  r4  total_strokes tourney_id
# 0  --  --             68  401056527
# 1  --  --             70  401056527
# 2  --  --             75  401056527
# 3  --  --             73  401056527
# 4  --  --             72  401056527
# 5  --  --             71  401056527

# %%
du.pull_tourney_leaderboard(6)
# Out:
#     pos                player to_par thru  r1  r2  r3  r4  total_strokes  \
# 0    T1     Bryson DeChambeau     -6    F  66  --  --  --             66
# 1    T1         Brooks Koepka     -6    F  66  --  --  --             66
# 2     3        Phil Mickelson     -5    F  67  --  --  --             67
# 3    T4           Ian Poulter     -4    F  68  --  --  --             68
# 4    T4        Dustin Johnson     -4    F  68  --  --  --             68
# 75  T73         Shugo Imahira     +4    F  76  --  --  --             76
# 76  T77   Kevin O'Connell (a)     +5    F  77  --  --  --             77
# 77  T77      Charl Schwartzel     +5    F  77  --  --  --             77
# 78  T77            Larry Mize     +5    F  77  --  --  --             77
# 79  T80           Shane Lowry     +6    F  78  --  --  --             78
# 80  T80          Fred Couples     +6    F  78  --  --  --             78
# 81  T80   Jose Maria Olazabal     +6    F  78  --  --  --             78
# 82  T80   Matthew Fitzpatrick     +6    F  78  --  --  --             78
# 83  T84           Ian Woosnam     +8    F  80  --  --  --             80
# 84  T84           Vijay Singh     +8    F  80  --  --  --             80
# 85   86            Paul Casey     +9    F  81  --  --  --             81
# 86   87         Angel Cabrera    +10    F  82  --  --  --             82
#
#    tourney_id           golfer on_team
# 0   401056527              NaN     NaN
# 1   401056527              NaN     NaN
# 2   401056527              NaN     NaN
# 3   401056527              NaN     NaN
# 4   401056527   Dustin Johnson     Yes
# 5   401056527              NaN     NaN
# 6   401056527              NaN     NaN
# 7   401056527              NaN     NaN
# 8   401056527              NaN     NaN
# 9   401056527              NaN     NaN
# 10  401056527              NaN     NaN
# 11  401056527              NaN     NaN
# 12  401056527              NaN     NaN
# 13  401056527              NaN     NaN
# 14  401056527              NaN     NaN
# 15  401056527              NaN     NaN
# 16  401056527              NaN     NaN
# 17  401056527              NaN     NaN
# 18  401056527              NaN     NaN
# 19  401056527        Jason Day     Yes
# 20  401056527              NaN     NaN
# 21  401056527              NaN     NaN
# 22  401056527              NaN     NaN
# 23  401056527  Tommy Fleetwood     Yes
# 24  401056527              NaN     NaN
# 25  401056527              NaN     NaN
# 26  401056527              NaN     NaN
# 27  401056527              NaN     NaN
# 28  401056527              NaN     NaN
# 29  401056527              NaN     NaN
# ..        ...              ...     ...
# 57  401056527              NaN     NaN
# 58  401056527              NaN     NaN
# 59  401056527              NaN     NaN
# 60  401056527              NaN     NaN
# 61  401056527              NaN     NaN
# 62  401056527              NaN     NaN
# 63  401056527              NaN     NaN
# 64  401056527              NaN     NaN
# 65  401056527              NaN     NaN
# 66  401056527              NaN     NaN
# 67  401056527              NaN     NaN
# 68  401056527              NaN     NaN
# 69  401056527              NaN     NaN
# 70  401056527      Justin Rose     Yes
# 71  401056527              NaN     NaN
# 72  401056527              NaN     NaN
# 73  401056527              NaN     NaN
# 74  401056527              NaN     NaN
# 75  401056527              NaN     NaN
# 76  401056527              NaN     NaN
# 77  401056527              NaN     NaN
# 78  401056527              NaN     NaN
# 79  401056527              NaN     NaN
# 80  401056527              NaN     NaN
# 81  401056527              NaN     NaN
# 82  401056527              NaN     NaN
# 83  401056527              NaN     NaN
# 84  401056527              NaN     NaN
# 85  401056527              NaN     NaN
# 86  401056527              NaN     NaN
#
# [87 rows x 12 columns]

# %%
with sqlite3.connect('/home/greenman225/Code/github/donkey_golf/donkey_golf/site.db') as db:
    print(pd.read_sql('SELECT * FROM teams', db))

# %%
du.pull_available_players()

# %%
du.pull_scoreboard()

# %%
du.pull_tourney_leaderboard(6)

# %%
du.scrape_espn_leaderboard()

# %%
du.data_load_leaderboard()

# %%
user_df = du.users_team(5)

# %%
df = du.pull_tourney_leaderboard()

# %%
df.head()

# %%
user_df.head()

# %%
final_df = df.merge(user_df[['golfer']],
        how='left',
        left_on=['player'],
        right_on=['golfer'])
final_df.loc[final_df['golfer'].notnull(), 'on_team'] = 'Yes'

# %%
final_df.loc[final_df['golfer'].notnull()]

# %%
final_df.head()

# %%
final_df

# %%
du.scrape_espn_leaderboard()['in']

# %%
random_dict = {'pre_t':'yup'}

# %%
if 'pre_t' in random_dict.keys():
    print('yas')

# %%
du.users_team(4)

# %%
du.player_map

# %%
du.pull_available_players()

# %%
df = du.scrape_world_rankings_data()

# %%
du.data_load_rankings()

# %%
df.loc[df['player'].str.contains('Kim')]

# %%
du.pull_available_players()

# %%
	name
0	user
1	pre_tourney
2	rankings

# %%
du.run_sql("SELECT * FROM rankings WHERE player LIKE ('%Kim%')")

# %%
du.run_sql('SELECT * FROM pre_tourney LIMIT 5')

# %%
def pull_
sql = '''SELECT a.*, b.current_rank, b.events_played FROM pre_tourney a
LEFT JOIN rankings b ON a.player=b.player
ORDER BY current_rank
'''
du.run_sql(sql)

# %%
du.run_sql('SELECT * ')

# %%
du.data_load_rankings()

# %%
import data_utils as du

# %%
du.pull_available_players()

# %%
du.data_load_leaderboard()

# %%
du.data_load_rankings()

# %%
du.run_sql('SELECT * FROM pre_tourney')

# %%
result = du.scrape_espn_leaderboard()

# %%
du.load_table_to_db(result.get('pre_tourney'), 'pre_tourney')

# %%
result.get('pre_tourney')

# %%
# Creating leaderboard & rankings dataframes
leaderboard = pd.read_html('http://www.espn.com/golf/leaderboard',header=3)[0]

leaderboard.columns = leaderboard.columns.str.lower().str.replace(' ','_')

if leaderboard.columns.tolist() == ['player', 'tee_time']:
    print("pre_tourney")

# %%
if leaderboard.columns.tolist() == ['player', 'tee_time']:
    print("pre_tourney")

# %%
conn = sqlite3.connect('/home/greenman225/Code/github/donkey_golf/donkey_golf/site.db')

# %%
pwd

# %%
du.scrape_espn_leaderboard()

# %%
du.data_load_leaderboard()

# %% [markdown]
# # Show all tables in our database

# %%
pd.read_sql('SELECT name FROM sqlite_master WHERE type = "table"', conn)

# %%
pd.read_sql('SELECT * from user', conn)
