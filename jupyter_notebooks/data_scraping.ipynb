# %%
import sqlite3
import pandas as pd

# %%
cd ../donkey_golf/
# Out:
# /home/greenman225/Code/github/donkey_golf/donkey_golf

# %%
import data_utils as du

# %%
du.pull_available_players()
# Out:
#                   player  tee_time
# 0          Andrew Landry   8:30 AM
# 1              Adam Long   8:30 AM
# 2          Corey Conners   8:30 AM
# 3         Keith Mitchell   8:41 AM
# 4             Kevin Tway   8:41 AM
# 5            Ian Woosnam   8:41 AM
# 6              Mike Weir   8:52 AM
# 7            Shane Lowry   8:52 AM
# 8    Kevin O'Connell (a)   8:52 AM
# 9         Justin Harding   9:03 AM
# 10         Angel Cabrera   9:03 AM
# 11            Aaron Wise   9:03 AM
# 12     Takumi Kanaya (a)   9:14 AM
# 13       Brandt Snedeker   9:14 AM
# 14         Danny Willett   9:14 AM
# 15           J.B. Holmes   9:25 AM
# 16          Fred Couples   9:25 AM
# 17            Si Woo Kim   9:25 AM
# 18     Lucas Bjerregaard   9:36 AM
# 19         Branden Grace   9:36 AM
# 20       Emiliano Grillo   9:36 AM
# 21       Eddie Pepperell   9:47 AM
# 22    Charles Howell III   9:47 AM
# 23      Charl Schwartzel   9:47 AM
# 24        Henrik Stenson   9:58 AM
# 25            Tony Finau   9:58 AM
# 26         Sergio Garcia   9:58 AM
# 27            Adam Scott  10:09 AM
# 28          Kyle Stanley  10:09 AM
# 29      Hideki Matsuyama  10:09 AM
# ..                   ...       ...
# 57       Bernhard Langer  12:10 PM
# 58      Alvaro Ortiz (a)  12:10 PM
# 59          Matt Wallace  12:10 PM
# 60   Matthew Fitzpatrick  12:32 PM
# 61       Alexander Noren  12:32 PM
# 62        Keegan Bradley  12:32 PM
# 63           Vijay Singh  12:43 PM
# 64        Billy Horschel  12:43 PM
# 65      Jovan Rebula (a)  12:43 PM
# 66         Shugo Imahira  12:54 PM
# 67          Kevin Kisner  12:54 PM
# 68  Kiradech Aphibarnrat  12:54 PM
# 69           Ian Poulter   1:05 PM
# 70          Zach Johnson   1:05 PM
# 71           Matt Kuchar   1:05 PM
# 72    Francesco Molinari   1:16 PM
# 73        Tyrrell Hatton   1:16 PM
# 74  Rafael Cabrera Bello   1:16 PM
# 75       Satoshi Kodaira   1:27 PM
# 76       Patrick Cantlay   1:27 PM
# 77          Bubba Watson   1:27 PM
# 78             Jason Day   1:38 PM
# 79        Dustin Johnson   1:38 PM
# 80     Bryson DeChambeau   1:38 PM
# 81         Justin Thomas   1:49 PM
# 82           Justin Rose   1:49 PM
# 83        Phil Mickelson   1:49 PM
# 84            Paul Casey   2:00 PM
# 85         Brooks Koepka   2:00 PM
# 86         Jordan Spieth   2:00 PM
#
# [87 rows x 2 columns]

# %%
du.data_load_leaderboard()

# %%
du.data_load_rankings()

# %%
du.run_sql('SELECT * FROM pre_tourney')

# %%
result = du.scrape_espn_leaderboard()

# %%
du.load_table_to_db(result.get('pre_tourney'), 'pre_tourney')

# %%
result.get('pre_tourney')

# %%
# Creating leaderboard & rankings dataframes
leaderboard = pd.read_html('http://www.espn.com/golf/leaderboard',header=3)[0]

leaderboard.columns = leaderboard.columns.str.lower().str.replace(' ','_')

if leaderboard.columns.tolist() == ['player', 'tee_time']:
    print("pre_tourney")

# %%
if leaderboard.columns.tolist() == ['player', 'tee_time']:
    print("pre_tourney")

# %%
conn = sqlite3.connect('/home/greenman225/Code/github/donkey_golf/donkey_golf/site.db')

# %%
pwd

# %%
du.scrape_espn_leaderboard()

# %%
du.data_load_leaderboard()

# %% [markdown]
# # Show all tables in our database

# %%
pd.read_sql('SELECT name FROM sqlite_master WHERE type = "table"', conn)

# %%
pd.read_sql('SELECT * from user', conn)
